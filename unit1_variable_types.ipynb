# %% [markdown]
# # Header Block
#
# Here is where you import all of the important packages and mount your google drive. (to access the data sets) All of the packages that you will need are already below, so this code will never have to be changed througout the semester.
#
# You will need to sign into your my.smccd.edu google account and make sure that you are mounting that shared drive. (and not your personal accounts)

# %%
# This header will be the same no matter what code you are using
# import modules that we will use multiple functions from and give them short names. 

import pandas as pd;
import numpy as np;
import seaborn as sb;
import matplotlib.pyplot as plt;


# import single functions

from scipy.stats.contingency import chi2_contingency;
from itertools import combinations;
from statsmodels.graphics.mosaicplot import mosaic;
from scipy.stats.contingency import chi2_contingency;
from scipy.stats import pearsonr;

# Automount the Google Drive to access data file. 

from google.colab import drive; 
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # The Data Block
#
# In this block we will import our data and do all of the management needed to do our analysis. Remember to always change the path
#
#
# ```
# "/content/drive/MyDrive/2022/Fall/Math 200/Data/s20-survey.csv"
# ```
#
# so that it matches where you moved the data folder in **YOUR** drive.

# %%
class_survey_data = pd.read_csv("/content/drive/MyDrive/2022/Fall/Math 200/Data/s20-survey.csv")
cereal_data = pd.read_csv("/content/drive/MyDrive/2022/Fall/Math 200/Data/cereal-data.csv")

# %%
class_survey_data
# Out:
#     gender  hcolor ecolor baseball football  distance            city  \
# 0     Male   Black  brown   Giants    49ers       3.5    Redwood City
# 1     Male   Black  brown   Giants    49ers      15.0    Redwood City
# 2   Female   Black  brown   Giants    49ers      11.1  East Palo Alto
# 3   Female   Brown  hazel   Giants  Raiders       7.0  East Palo Alto
# 4     Male   Brown  brown   Giants    49ers       1.0        Woodside
# ..     ...     ...    ...      ...      ...       ...             ...
# 77    Male   Black  brown   Giants    49ers       9.0    Redwood City
# 78  Female   Brown  green   Giants    49ers      28.0   San Francisco
# 79  Female  Blonde  brown   Giants    49ers       7.1      Menlo Park
# 80    Male   Brown  brown   Giants    49ers       3.0         Redwood
# 81    Male   Black  brown   Giants    49ers      15.0      San Mateo
#
#     time_commute         work love_stats m190  cig   mj  height  weight
# ...

# %%
cereal_data
# Out:
#                     Name    Manufacturer Target   Shelf  Calories  Carbs  Fat  \
# 0              100% Bran         Nabisco  adult     top        70    5.0    1
# 1      100% Natural Bran     Quaker Oats  adult     top       120    8.0    5
# 2               All-Bran        Kelloggs  adult     top        70    7.0    1
# 3   All-Bran Extra Fiber        Kelloggs  adult     top        50    8.0    0
# 4         Almond Delight  Ralston Purina  adult     top       110   14.0    2
# ..                   ...             ...    ...     ...       ...    ...  ...
# 72               Triples   General Mills  adult     top       110   21.0    1
# 73                  Trix   General Mills  child  middle       110   13.0    1
# 74            Wheat Chex  Ralston Purina  adult  bottom       100   17.0    1
# 75              Wheaties   General Mills  child  bottom       100   17.0    1
# 76   Wheaties Honey Gold   General Mills  child  bottom       110   16.0    1
#
# ...
